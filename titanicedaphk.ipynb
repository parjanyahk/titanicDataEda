# %%
#Import statements

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
#Reading the TITANIC.csv file

teda = pd.read_csv('C:\\Users\\Parjanya\\Downloads\\TITANIC.csv')

# %%
#Variable Identification

# %%
#To view the first 5 data

teda.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
#To view the info of the whole project

teda.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 66.2+ KB

# %%
teda.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
#Dropping the columns cabin because it has too many NaN values, and others because they are pretty useless

teda_cleaned = teda.drop(['PassengerId', 'Name', 'Ticket', 'Cabin'], axis=1)
teda_cleaned.head()
# Out:
#    Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 0         0       3    male  22.0      1      0   7.2500        S
# 1         1       1  female  38.0      1      0  71.2833        C
# 2         1       3  female  26.0      0      0   7.9250        S
# 3         1       1  female  35.0      1      0  53.1000        S
# 4         0       3    male  35.0      0      0   8.0500        S

# %%
#Univariate Analysis

# %%
#Count plot of the people who survived and those who didn't

sns.set_style('whitegrid')
plt.figure(figsize= (12, 7))
sns.countplot('Survived', data = teda_cleaned)

# %%
#Count plot of the Pclass

sns.set_style('whitegrid')
plt.figure(figsize= (12, 7))
sns.countplot('Pclass', data = teda_cleaned)

# %%
#Count plot for sex

sns.set_style('whitegrid')
plt.figure(figsize= (12, 7))
sns.countplot('Sex', data = teda_cleaned)

# %%
#Count plot for Embarked

sns.set_style('whitegrid')
plt.figure(figsize= (12, 7))
sns.countplot(x = 'Embarked', data = teda_cleaned)

# %%
#Box plot for Age

sns.set_style('whitegrid')
plt.figure(figsize= (12, 7))
sns.boxplot(y= 'Age', data=teda_cleaned)

# %%
#Box plot for SibSp

sns.set_style('whitegrid')
plt.figure(figsize= (12, 7))
sns.boxplot(y= 'SibSp', data=teda_cleaned)

# %%
#distplot for SibSp

sns.set_style('whitegrid')
plt.figure(figsize= (12, 7))
sns.distplot(teda_cleaned['SibSp'], bins=10)

# %%
#Box plot for Parch

sns.set_style('whitegrid')
plt.figure(figsize= (12, 7))
sns.boxplot(y= 'Parch', data=teda_cleaned)

# %%
#distplot for Parch

sns.set_style('whitegrid')
plt.figure(figsize= (12, 7))
sns.distplot(teda_cleaned['Parch'], bins=10)

# %%
#Box plot for Fare

sns.set_style('whitegrid')
plt.figure(figsize= (12, 10))
sns.boxplot(y= 'Fare', data=teda_cleaned)

# %%
#distplot for Fare

sns.set_style('whitegrid')
plt.figure(figsize= (12, 10))
sns.distplot(teda_cleaned['Fare'], bins=10)

# %%
#Bivariate Analysis

# %%
#For Continuous vs Continuous data

# %%
#Scatter plot of Age vs Sibsp


plt.figure(figsize= (12, 10))
plt.scatter(teda_cleaned['Age'], teda_cleaned['SibSp'])
plt.title('Age vs SibSp')
plt.xlabel('Age')
plt.ylabel('SibSp')
# Out:
# Text(0, 0.5, 'SibSp')

# %%
#Scatter plot of Age vs Parch


plt.figure(figsize= (12, 10))
plt.scatter(teda_cleaned['Age'], teda_cleaned['Parch'])
plt.title('Age vs Parch')
plt.xlabel('Age')
plt.ylabel('Parch')
# Out:
# Text(0, 0.5, 'Parch')

# %%
#Scatterplot of Age vs Fare

plt.figure(figsize= (12, 10))
plt.scatter(teda_cleaned['Age'], teda_cleaned['Fare'])
plt.title('Age vs Fare')
plt.xlabel('Age')
plt.ylabel('Fare')
# Out:
# Text(0, 0.5, 'Fare')

# %%
plt.figure(figsize= (12, 10))
plt.scatter(teda_cleaned['SibSp'], teda_cleaned['Parch'])
plt.title('SibSp vs Parch')
plt.xlabel('SibSp')
plt.ylabel('Parch')
# Out:
# Text(0, 0.5, 'Parch')

# %%
plt.figure(figsize= (12, 10))
plt.scatter(teda_cleaned['SibSp'], teda_cleaned['Fare'])
plt.title('SibSp vs Fare')
plt.xlabel('SibSp')
plt.ylabel('Fare')
# Out:
# Text(0, 0.5, 'Fare')

# %%
plt.figure(figsize= (12, 10))
plt.scatter(teda_cleaned['Parch'], teda_cleaned['Fare'])
plt.title('Parch vs Fare')
plt.xlabel('Parch')
plt.ylabel('Fare')
# Out:
# Text(0, 0.5, 'Fare')

# %%
#For Continuous vs Categorical data

# %%
plt.figure(figsize= (12, 10))
plt.scatter(teda_cleaned['Age'], teda_cleaned['Survived'])
plt.title('Age vs Survived')
plt.xlabel('Age')
plt.ylabel('Survived')
# Out:
# Text(0, 0.5, 'Survived')

# %%
plt.figure(figsize= (12, 10))
plt.scatter(teda_cleaned['Age'], teda_cleaned['Pclass'])
plt.title('Age vs Pclass')
plt.xlabel('Age')
plt.ylabel('Pclass')
# Out:
# Text(0, 0.5, 'Pclass')

# %%
plt.figure(figsize= (12, 10))
plt.scatter(teda_cleaned['Age'], teda_cleaned['Sex'])
plt.title('Age vs Sex')
plt.xlabel('Age')
plt.ylabel('Sex')
# Out:
# Text(0, 0.5, 'Sex')

# %%
plt.figure(figsize= (12, 10))
plt.scatter(teda_cleaned['Age'], teda_cleaned['Embarked'])
plt.title('Age vs Embarked')
plt.xlabel('Age')
plt.ylabel('Embarked')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-33-9fc59051d34d> in <module>
#       1 plt.figure(figsize= (12, 10))
# ----> 2 plt.scatter(teda_cleaned['Age'], teda_cleaned['Embarked'])
#       3 plt.title('Age vs Embarked')
#       4 plt.xlabel('Age')
#       5 plt.ylabel('Embarked')
#
# c:\users\parjanya\appdata\local\programs\python\python37-32\lib\site-packages\matplotlib\pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, plotnonfinite, data, **kwargs)
#    2814         verts=verts, edgecolors=edgecolors,
#    2815         plotnonfinite=plotnonfinite, **({"data": data} if data is not
# -> 2816         None else {}), **kwargs)
#    2817     sci(__ret)
#    2818     return __ret
#
# ...

# %%
plt.scatter(teda_cleaned['SibSp'], teda_cleaned['Survived'])
plt.title('SibSp vs Survived')
plt.xlabel('SibSp')
plt.ylabel('Survived')
# Out:
# Text(0, 0.5, 'Survived')

# %%
plt.scatter(teda_cleaned['SibSp'], teda_cleaned['Pclass'])
plt.title('SibSp vs Pclass')
plt.xlabel('SibSp')
plt.ylabel('Pclass')
# Out:
# Text(0, 0.5, 'Pclass')

# %%
plt.scatter(teda_cleaned['SibSp'], teda_cleaned['Sex'])
plt.title('SibSp vs Sex')
plt.xlabel('SibSp')
plt.ylabel('Sex')
# Out:
# Text(0, 0.5, 'Sex')

# %%
plt.figure(figsize= (12, 10))
plt.scatter(teda_cleaned['SibSp'], teda_cleaned['Embarked'])
plt.title('SibSp vs Embarked')
plt.xlabel('SibSp')
plt.ylabel('Embarked')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-38-d3d49793eb9a> in <module>
#       1 plt.figure(figsize= (12, 10))
# ----> 2 plt.scatter(teda_cleaned['SibSp'], teda_cleaned['Embarked'])
#       3 plt.title('SibSp vs Embarked')
#       4 plt.xlabel('SibSp')
#       5 plt.ylabel('Embarked')
#
# c:\users\parjanya\appdata\local\programs\python\python37-32\lib\site-packages\matplotlib\pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, plotnonfinite, data, **kwargs)
#    2814         verts=verts, edgecolors=edgecolors,
#    2815         plotnonfinite=plotnonfinite, **({"data": data} if data is not
# -> 2816         None else {}), **kwargs)
#    2817     sci(__ret)
#    2818     return __ret
#
# ...

# %%
plt.scatter(teda_cleaned['Parch'], teda_cleaned['Survived'])
plt.title('Parch vs Survived')
plt.xlabel('Parch')
plt.ylabel('Survived')
# Out:
# Text(0, 0.5, 'Survived')

# %%
plt.scatter(teda_cleaned['Parch'], teda_cleaned['Pclass'])
plt.title('Parch vs Pclass')
plt.xlabel('Parch')
plt.ylabel('Pclass')
# Out:
# Text(0, 0.5, 'Pclass')

# %%
plt.scatter(teda_cleaned['Parch'], teda_cleaned['Sex'])
plt.title('Parch vs Sex')
plt.xlabel('Parch')
plt.ylabel('Sex')
# Out:
# Text(0, 0.5, 'Sex')

# %%
plt.scatter(teda_cleaned['Parch'], teda_cleaned['Embarked'])
plt.title('Parch vs Embarked')
plt.xlabel('Parch')
plt.ylabel('Embarked')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-43-7781c3f13ec1> in <module>
# ----> 1 plt.scatter(teda_cleaned['Parch'], teda_cleaned['Embarked'])
#       2 plt.title('Parch vs Embarked')
#       3 plt.xlabel('Parch')
#       4 plt.ylabel('Embarked')
#       5
#
# c:\users\parjanya\appdata\local\programs\python\python37-32\lib\site-packages\matplotlib\pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, plotnonfinite, data, **kwargs)
#    2814         verts=verts, edgecolors=edgecolors,
#    2815         plotnonfinite=plotnonfinite, **({"data": data} if data is not
# -> 2816         None else {}), **kwargs)
#    2817     sci(__ret)
#    2818     return __ret
#
# c:\users\parjanya\appdata\local\programs\python\python37-32\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
# ...

# %%
plt.figure(figsize= (12, 10))
plt.scatter(teda_cleaned['Fare'], teda_cleaned['Survived'])
plt.title('Fare vs Survived')
plt.xlabel('Fare')
plt.ylabel('Survived')
# Out:
# Text(0, 0.5, 'Survived')

# %%
plt.figure(figsize= (12, 10))
plt.scatter(teda_cleaned['Fare'], teda_cleaned['Pclass'])
plt.title('Fare vs Pclass')
plt.xlabel('Fare')
plt.ylabel('Pclass')
# Out:
# Text(0, 0.5, 'Pclass')

# %%
plt.figure(figsize= (12, 10))
plt.scatter(teda_cleaned['Fare'], teda_cleaned['Sex'])
plt.title('Fare vs Sex')
plt.xlabel('Fare')
plt.ylabel('Sex')
# Out:
# Text(0, 0.5, 'Sex')

# %%
plt.figure(figsize= (12, 10))
plt.scatter(teda_cleaned['Fare'], teda_cleaned['Embarked'])
plt.title('Fare vs Embarked')
plt.xlabel('Fare')
plt.ylabel('Embarked')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-47-59bac37b2bd4> in <module>
#       1 plt.figure(figsize= (12, 10))
# ----> 2 plt.scatter(teda_cleaned['Fare'], teda_cleaned['Embarked'])
#       3 plt.title('Fare vs Embarked')
#       4 plt.xlabel('Fare')
#       5 plt.ylabel('Embarked')
#
# c:\users\parjanya\appdata\local\programs\python\python37-32\lib\site-packages\matplotlib\pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, plotnonfinite, data, **kwargs)
#    2814         verts=verts, edgecolors=edgecolors,
#    2815         plotnonfinite=plotnonfinite, **({"data": data} if data is not
# -> 2816         None else {}), **kwargs)
#    2817     sci(__ret)
#    2818     return __ret
#
# ...

# %%
#For Categorical vs Categorical data

# %%
#groupby for survived and pclass

surpclcount = teda_cleaned.groupby(['Survived','Pclass'], axis=0)
surpclcount.size()
# Out:
# Survived  Pclass
# 0         1          80
#           2          97
#           3         372
# 1         1         136
#           2          87
#           3         119
# dtype: int64

# %%
sursexcount = teda_cleaned.groupby(['Survived','Sex'], axis=0)
sursexcount.size()
# Out:
# Survived  Sex
# 0         female     81
#           male      468
# 1         female    233
#           male      109
# dtype: int64

# %%
surembcount = teda_cleaned.groupby(['Survived','Embarked'], axis=0)
surembcount.size()
# Out:
# Survived  Embarked
# 0         C            75
#           Q            47
#           S           427
# 1         C            93
#           Q            30
#           S           217
# dtype: int64

# %%
pclsexcount = teda_cleaned.groupby(['Pclass','Sex'], axis=0)
pclsexcount.size()
# Out:
# Pclass  Sex
# 1       female     94
#         male      122
# 2       female     76
#         male      108
# 3       female    144
#         male      347
# dtype: int64

# %%
pclembcount = teda_cleaned.groupby(['Pclass','Embarked'], axis=0)
pclembcount.size()
# Out:
# Pclass  Embarked
# 1       C            85
#         Q             2
#         S           127
# 2       C            17
#         Q             3
#         S           164
# 3       C            66
#         Q            72
#         S           353
# dtype: int64

# %%
sexembcount = teda_cleaned.groupby(['Sex','Embarked'], axis=0)
sexembcount.size()
# Out:
# Sex     Embarked
# female  C            73
#         Q            36
#         S           203
# male    C            95
#         Q            41
#         S           441
# dtype: int64

# %%
pd.crosstab(teda_cleaned['Survived'], teda_cleaned['Pclass']).plot(kind='bar', stacked=True)

# %%
pd.crosstab(teda_cleaned['Survived'], teda_cleaned['Sex']).plot(kind='bar', stacked=True)

# %%
pd.crosstab(teda_cleaned['Survived'], teda_cleaned['Embarked']).plot(kind='bar', stacked=True)

# %%
pd.crosstab(teda_cleaned['Pclass'], teda_cleaned['Sex']).plot(kind='bar', stacked=True)

# %%
pd.crosstab(teda_cleaned['Pclass'], teda_cleaned['Embarked']).plot(kind='bar', stacked=True)

# %%
pd.crosstab(teda_cleaned['Sex'], teda_cleaned['Embarked']).plot(kind='bar', stacked=True)

# %%
#Missing value Treatment

# %%
teda_cleaned.isnull()
# Out:
#      Survived  Pclass    Sex    Age  SibSp  Parch   Fare  Embarked
# 0       False   False  False  False  False  False  False     False
# 1       False   False  False  False  False  False  False     False
# 2       False   False  False  False  False  False  False     False
# 3       False   False  False  False  False  False  False     False
# 4       False   False  False  False  False  False  False     False
# ..        ...     ...    ...    ...    ...    ...    ...       ...
# 886     False   False  False  False  False  False  False     False
# 887     False   False  False  False  False  False  False     False
# 888     False   False  False   True  False  False  False     False
# 889     False   False  False  False  False  False  False     False
# 890     False   False  False  False  False  False  False     False
#
# [891 rows x 8 columns]

# %%
teda_cleaned.isnull().values.any()
# Out:
# True

# %%
teda_cleaned.isnull().sum()
# Out:
# Survived      0
# Pclass        0
# Sex           0
# Age         177
# SibSp         0
# Parch         0
# Fare          0
# Embarked      2
# dtype: int64

# %%
teda_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  891 non-null    int64
#  1   Pclass    891 non-null    int64
#  2   Sex       891 non-null    object
#  3   Age       714 non-null    float64
#  4   SibSp     891 non-null    int64
#  5   Parch     891 non-null    int64
#  6   Fare      891 non-null    float64
#  7   Embarked  889 non-null    object
# dtypes: float64(2), int64(4), object(2)
# memory usage: 48.8+ KB

# %%
#We see that age and embarked have missing values

# %%
#treating missing values in Age

# %%
teda_cleaned.describe()
# Out:
#          Survived      Pclass         Age       SibSp       Parch        Fare
# count  891.000000  891.000000  891.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.361582    0.523008    0.381594   32.204208
# std      0.486592    0.836071   13.019697    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   22.000000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   35.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
#Heat map depiction of the null values

sns.set_style('whitegrid')
plt.figure(figsize= (12, 7))
sns.heatmap(teda_cleaned.isnull(), yticklabels= False)

# %%
teda_cleaned.hist(column=['Age'], bins=7)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x012F99F0>]],
#       dtype=object)

# %%
teda_cleaned['Age']=teda_cleaned['Age'].fillna(value=teda_cleaned['Age'].median())

# %%
teda_cleaned
# Out:
#      Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 0           0       3    male  22.0      1      0   7.2500        S
# 1           1       1  female  38.0      1      0  71.2833        C
# 2           1       3  female  26.0      0      0   7.9250        S
# 3           1       1  female  35.0      1      0  53.1000        S
# 4           0       3    male  35.0      0      0   8.0500        S
# ..        ...     ...     ...   ...    ...    ...      ...      ...
# 886         0       2    male  27.0      0      0  13.0000        S
# 887         1       1  female  19.0      0      0  30.0000        S
# 888         0       3  female  28.0      1      2  23.4500        S
# 889         1       1    male  26.0      0      0  30.0000        C
# 890         0       3    male  32.0      0      0   7.7500        Q
#
# [891 rows x 8 columns]

# %%
teda_cleaned.isnull().sum()
# Out:
# Survived    0
# Pclass      0
# Sex         0
# Age         0
# SibSp       0
# Parch       0
# Fare        0
# Embarked    2
# dtype: int64

# %%
#treating missing values in Embarked
