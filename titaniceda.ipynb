# %%
#Import statements

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

#In this data, the dependent value is Survived. Rest all are independent values.

# %%
#Reading the TITANIC.csv file

train = pd.read_csv('C:\\Users\\Parjanya\\Downloads\\TITANIC.csv')

# %%
#Variable Identification

# %%
#To view the first 5 data

train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
#To view the info of the whole project

train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 66.2+ KB

# %%
train.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
#To view the NaN values

train.isnull()
# Out:
#      PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 0          False     False   False  False  False  False  False  False   False
# 1          False     False   False  False  False  False  False  False   False
# 2          False     False   False  False  False  False  False  False   False
# 3          False     False   False  False  False  False  False  False   False
# 4          False     False   False  False  False  False  False  False   False
# ..           ...       ...     ...    ...    ...    ...    ...    ...     ...
# 886        False     False   False  False  False  False  False  False   False
# 887        False     False   False  False  False  False  False  False   False
# 888        False     False   False  False  False   True  False  False   False
# 889        False     False   False  False  False  False  False  False   False
# 890        False     False   False  False  False  False  False  False   False
#
#       Fare  Cabin  Embarked
# ...

# %%
#To view the count of NaN values in the data set

train.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
#Heat map depiction of the null values

sns.set_style('whitegrid')
plt.figure(figsize= (12, 7))
sns.heatmap(train.isnull(), yticklabels= False)

# %%
#Univatiate Data Analysis

# %%
#Count plot of the people who survived and those who didn't

sns.set_style('whitegrid')
plt.figure(figsize= (12, 7))
sns.countplot('Survived', data = train)

# %%
#Count plot of the Pclass

sns.set_style('whitegrid')
plt.figure(figsize= (12, 7))
sns.countplot('Pclass', data = train)

# %%
#Count plot for sex

sns.set_style('whitegrid')
plt.figure(figsize= (12, 7))
sns.countplot('Sex', data = train)

# %%
#Count plot of people having siblings or spouse

sns.set_style('whitegrid')
plt.figure(figsize= (12, 7))
sns.countplot(x = 'SibSp', data = train)

# %%
#Count plot for Parch

sns.set_style('whitegrid')
plt.figure(figsize= (12, 7))
sns.countplot(x = 'Parch', data = train)

# %%
#Count plot for Embarked

sns.set_style('whitegrid')
plt.figure(figsize= (12, 7))
sns.countplot(x = 'Embarked', data = train)

# %%
#Distplot to view the age distribution

sns.set_style('whitegrid')
plt.figure(figsize= (12, 7))
sns.distplot(train['Age'].dropna(), kde = False)

# %%
#Distplot to view fare distribution

sns.set_style('whitegrid')
plt.figure(figsize= (12, 7))
sns.distplot(train['Fare'], kde = False, bins=20)

# %%
#Bivariate Data Analysis

# %%
#Ratio of sex the people who survived and those who didn't.
#Where, Deceased = 0, Survived = 1

sns.set_style('whitegrid')
plt.figure(figsize= (12, 7))
sns.countplot(x = 'Survived', hue = 'Sex', data = train)

# %%
plt.figure(figsize= (12, 7))
sns.heatmap(train.corr(), annot=True, linewidth=0.5)

# %%
#Correlation of survived

train.corr(method='pearson')
# Out:
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.005007 -0.035144  0.036847 -0.057527 -0.001652
# Survived       -0.005007  1.000000 -0.338481 -0.077221 -0.035322  0.081629
# Pclass         -0.035144 -0.338481  1.000000 -0.369226  0.083081  0.018443
# Age             0.036847 -0.077221 -0.369226  1.000000 -0.308247 -0.189119
# SibSp          -0.057527 -0.035322  0.083081 -0.308247  1.000000  0.414838
# Parch          -0.001652  0.081629  0.018443 -0.189119  0.414838  1.000000
# Fare            0.012658  0.257307 -0.549500  0.096067  0.159651  0.216225
#
#                  Fare
# PassengerId  0.012658
# Survived     0.257307
# Pclass      -0.549500
# Age          0.096067
# SibSp        0.159651
# Parch        0.216225
# Fare         1.000000

# %%
#From above correlation table we can see that Survival is inversely correlated to Pclass
#i.e., Class 1 had better survival rate compared to other classes.
#We can also see that Age and Survival are slightly correlated.

# %%
#Role of class in survived

grouped_by_pclass = train.groupby(['Pclass', 'Survived', 'Sex'])
grouped_by_pclass.size()
# Out:
# Pclass  Survived  Sex
# 1       0         female      3
#                   male       77
#         1         female     91
#                   male       45
# 2       0         female      6
#                   male       91
#         1         female     70
#                   male       17
# 3       0         female     72
#                   male      300
#         1         female     72
#                   male       47
# dtype: int64

# %%
train.groupby(['Pclass', 'Sex']).describe()
# Out:
#               PassengerId                                               \
#                     count        mean         std   min     25%    50%
# Pclass Sex
# 1      female        94.0  469.212766  247.476723   2.0  293.50  447.0
#        male         122.0  455.729508  247.026449   7.0  255.50  480.5
# 2      female        76.0  443.105263  243.627288  10.0  269.75  439.5
#        male         108.0  447.962963  256.922546  18.0  225.75  416.5
# 3      female       144.0  399.729167  267.232416   3.0  165.25  376.0
#        male         347.0  455.515850  261.921251   1.0  209.50  466.0
#
#                              Survived            ... Parch        Fare  \
#                   75%    max    count      mean  ...   75%  max  count
# Pclass Sex                                       ...
# 1      female  698.25  888.0     94.0  0.968085  ...   1.0  2.0   94.0
#        male    660.75  890.0    122.0  0.368852  ...   0.0  4.0  122.0
# ...

# %%
sns.set_style('whitegrid')
plt.figure(figsize= (12, 7))
sns.countplot(x = 'Survived', hue = 'Pclass', data = train)

# %%
#Dropping the columns cabin because it has too many NaN values,
#and others because they are pretty useless

train_cleaned = train.drop(['PassengerId', 'Name', 'Ticket', 'Cabin'], axis=1)
train_cleaned.head()
# Out:
#    Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 0         0       3    male  22.0      1      0   7.2500        S
# 1         1       1  female  38.0      1      0  71.2833        C
# 2         1       3  female  26.0      0      0   7.9250        S
# 3         1       1  female  35.0      1      0  53.1000        S
# 4         0       3    male  35.0      0      0   8.0500        S

# %%
train_cleaned.isnull().sum()
# Out:
# Survived      0
# Pclass        0
# Sex           0
# Age         177
# SibSp         0
# Parch         0
# Fare          0
# Embarked      2
# dtype: int64

# %%
#

sns.set_style('whitegrid')
plt.figure(figsize= (12, 7))
sns.boxplot(x = 'Pclass', y = 'Age', data = train)

# %%
sns.set_style('whitegrid')
plt.figure(figsize= (12, 7))
train.boxplot(column=['Age'])

# %%
#Removing null values from age and filling it  using mean

train_cleaned["Age"].fillna(train_cleaned.Age.mean(), inplace=True)
train_cleaned.describe()
# Out:
#          Survived      Pclass         Age       SibSp       Parch        Fare
# count  891.000000  891.000000  891.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   13.002015    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   22.000000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   29.699118    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   35.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
train_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  891 non-null    int64
#  1   Pclass    891 non-null    int64
#  2   Sex       891 non-null    object
#  3   Age       891 non-null    float64
#  4   SibSp     891 non-null    int64
#  5   Parch     891 non-null    int64
#  6   Fare      891 non-null    float64
#  7   Embarked  889 non-null    object
# dtypes: float64(2), int64(4), object(2)
# memory usage: 48.8+ KB

# %%
#Removing null values from Embarked

train_cleaned["Embarked"].fillna(value = "Southampton", inplace=True)
train_cleaned.describe()
# Out:
#          Survived      Pclass         Age       SibSp       Parch        Fare
# count  891.000000  891.000000  891.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   13.002015    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   22.000000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   29.699118    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   35.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
train_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  891 non-null    int64
#  1   Pclass    891 non-null    int64
#  2   Sex       891 non-null    object
#  3   Age       891 non-null    float64
#  4   SibSp     891 non-null    int64
#  5   Parch     891 non-null    int64
#  6   Fare      891 non-null    float64
#  7   Embarked  891 non-null    object
# dtypes: float64(2), int64(4), object(2)
# memory usage: 48.8+ KB

# %%
#Heatmap of no null values

sns.set_style('whitegrid')
plt.figure(figsize= (12, 7))
sns.heatmap(train_cleaned.isnull(), yticklabels= False)

# %%
#treatment of outliers

# %%
sns.set_style('whitegrid')
plt.figure(figsize= (12, 7))
train_cleaned.boxplot(column=['Age'])

# %%
sns.set_style('whitegrid')
plt.figure(figsize= (12, 7))
train_cleaned.boxplot(column = ['Age'])

# %%
#below part is messed up, idk what done wrong

# %%
IQR_Age = train_cleaned['Age'].quantile(0.75) - train_cleaned['Age'].quantile(0.25)
print(IQR_Age)
# Out:
# 13.0

# %%
Upper_OutlierLimit_Age = train_cleaned['Age'].quantile(0.75) + 1.5*IQR_Age
Lower_OutlierLimit_Age = train_cleaned['Age'].quantile(0.25) - 1.5*IQR_Age
print(Upper_OutlierLimit_Age)
print(Lower_OutlierLimit_Age)
# Out:
# 54.5
# 2.5

# %%
OutlierValues_Age = train_cleaned[(train_cleaned['Age']>=Upper_OutlierLimit_Age) | (train_cleaned['Age']<=Lower_OutlierLimit_Age)]

# %%
OutlierValues_Age
# Out:
#      Survived  Pclass     Sex    Age  SibSp  Parch     Fare     Embarked
# 7           0       3    male   2.00      3      1  21.0750            S
# 11          1       1  female  58.00      0      0  26.5500            S
# 15          1       2  female  55.00      0      0  16.0000            S
# 16          0       3    male   2.00      4      1  29.1250            Q
# 33          0       2    male  66.00      0      0  10.5000            S
# ..        ...     ...     ...    ...    ...    ...      ...          ...
# 827         1       2    male   1.00      0      2  37.0042            C
# 829         1       1  female  62.00      0      0  80.0000  Southampton
# 831         1       2    male   0.83      1      1  18.7500            S
# 851         0       3    male  74.00      0      0   7.7750            S
# 879         1       1  female  56.00      0      1  83.1583            C
#
# [66 rows x 8 columns]

# %%
train_cleaned['Age'] = train_cleaned['Age'].quantile(0.95)

# %%
train_cleaned['Age']
# Out:
# 0      54.0
# 1      54.0
# 2      54.0
# 3      54.0
# 4      54.0
#        ...
# 886    54.0
# 887    54.0
# 888    54.0
# 889    54.0
# 890    54.0
# Name: Age, Length: 891, dtype: float64
